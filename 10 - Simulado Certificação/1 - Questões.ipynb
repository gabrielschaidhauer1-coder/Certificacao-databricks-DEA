# %% [markdown]
# ### 1 - Quais das afirmações a seguir descrevem corretamente a Plataforma Databricks Lakehouse?
#
# A) A Plataforma Databricks Lakehouse é a substituição dos data warehouses.
#
# B) A Plataforma Databricks Lakehouse é adequada apenas para workloads de dados em streaming, para processar dados em tempo real.
#
# C) A Plataforma Databricks Lakehouse não oferece suporte a casos de uso de BI (Business Intelligence).
#
# D) A Plataforma Databricks Lakehouse combina os melhores elementos dos data lakes e dos data warehouses para oferecer confiabilidade, forte governança e alto desempenho.
#
# E) A Plataforma Databricks Lakehouse foi projetada apenas para workloads de dados em batch com grandes volumes de dados.

# %% [markdown]
# ### 2 - Qual dos seguintes eventos **não** acontecerá quando um cluster é encerrado no Databricks?
#
# A) As máquinas virtuais associadas e a memória operacional serão apagadas
#
# B) O armazenamento de volumes anexados será excluído
#
# C) As conexões de rede entre os nós serão removidas
#
# D) O estado de execução e o cache serão limpos
#
# E) Os códigos e arquivos de dados que você salvou anteriormente serão perdidos

# %% [markdown]
# ### 3 - Como você pode injetar as variáveis Python chamadas `table_name` e `database_name` em uma query SQL e executá-la usando PySpark?
#
# A) `spark.sql(f"SELECT * FROM {database_name}+{table_name}")`
#
# B) `spark.sql(f"SELECT * FROM [database_name].[table_name]")`
#
# C) `spark.sql(f"SELECT * FROM {database_name}.{table_name}")`
#
# D) `spark.sql(f"SELECT * FROM (database_name).(table_name)")`
#
# E) `spark.sql("SELECT * FROM .")`

# %% [markdown]
# ### 4 - Um dataset foi definido usando Delta Live Tables e inclui a seguinte cláusula de expectativa:
#
# `CONSTRAINT valid_age EXPECT (age > 0) ON VIOLATION FAIL UPDATE`
#
# #### Qual é o comportamento esperado quando um batch de dados de entrada que viola essa restrição é processado?
#
# A) Os registros que violam a expectativa são descartados do dataset de destino e registrados como inválidos no event log.
#
# B) Os registros que violam a expectativa são adicionados ao dataset de destino e registrados como inválidos no event log.
#
# C) Os registros que violam a expectativa são adicionados ao dataset de destino e marcados como inválidos em um campo adicional criado no dataset de destino.
#
# D) Os registros que violam a expectativa fazem com que a task falhe.
#
# E) Os registros que violam a expectativa são descartados do dataset de destino e carregados em uma tabela de quarentena.

# %% [markdown]
# ### 5 - Quantos dias de histórico de execuções de jobs são preservados pelo Databricks?
#
# A) 30
#
# B) 45
#
# C) 60
#
# D) 90
#
# E) 120

# %% [markdown]
# ### 6 - Qual é o nome da coluna adicionada automaticamente pelo Auto Loader para capturar quaisquer dados que possam estar malformados e não se encaixem na tabela durante a ingestão incremental de dados?
#
# A) rescued_data
#
# B) rescued_data_
#
# C) _rescued_data
#
# D) _rescued_data_
#
# E) rescuedData

# %% [markdown]
# ### 7 - Um engenheiro de dados percebe que os arquivos de dados vinculados a uma tabela Delta estão anormalmente pequenos, levando a uma performance subótima. Ele decide consolidar esses pequenos arquivos em menos arquivos maiores para melhorar a eficiência das consultas. Qual comando deve ser utilizada para realizar essa consolidação?
#
# A) REDUCE
#
# B) OPTIMIZE
#
# C) REPARTITION
#
# D) COMPACTION
#
# E) VACUUM

# %% [markdown]
# ### 8 - Qual das seguintes queries de Structured Streaming está realizando um *hop* de uma tabela **Silver** para uma tabela **Gold**?
#
# A)
# ```python
# (spark.table("sales")
#  .groupBy("store")
#  .agg(sum("sales"))
#  .writeStream
#  .option("checkpointLocation", checkpointPath)
#  .outputMode("complete")
#  .table("newSales")
# )
#
# B)
# (spark.table("sales")
#  .withColumn("avgPrice", col("sales") / col("units"))
#  .writeStream
#  .option("checkpointLocation", checkpointPath)
#  .outputMode("append")
#  .table("newSales")
# )
#
# C)
# (spark.read.load(rawSalesLocation)
#  .writeStream
#  .option("checkpointLocation", checkpointPath)
#  .outputMode("append")
#  .table("newSales")
# )
#
# D)
# (spark.table("sales")
#  .filter(col("units") > 0)
#  .writeStream
#  .option("checkpointLocation", checkpointPath)
#  .outputMode("append")
#  .table("newSales")
# )
#
# E)
# (spark.readStream.load(rawSalesLocation)
#  .writeStream
#  .option("checkpointLocation", checkpointPath)
#  .outputMode("append")
#  .table("newSales")
# )

# %% [markdown]
# ### 9 - Qual das opções de SQL DDL abaixo pode ser usada para criar uma UDF que converte valores de distância de Milhas para KM e vice-versa?
# **Nota:** Se qualquer outra unidade de medida for fornecida, a função deve retornar o mesmo valor.
#
# A)
# ```sql
# CREATE UDF convert_distance(distance DOUBLE, measure STRING)
# RETURN
# CASE
#   WHEN measure = "Miles" THEN (distance * 1.60934)
#   WHEN measure = "KM" THEN (distance * 0.621371)
#   ELSE distance
# END;
#
# B)
# CREATE UDF FUNCTION convert_distance(distance DOUBLE, measure STRING)
# RETURN
# CASE
#   WHEN measure = "Miles" THEN (distance * 1.60934)
#   WHEN measure = "KM" THEN (distance * 0.621371)
#   ELSE distance
# END;
#
# C)
# CREATE FUNCTION convert_distance(distance DOUBLE, measure STRING)
# RETURN
# CASE
#   WHEN measure = "Miles" THEN (distance * 1.60934)
#   WHEN measure = "KM" THEN (distance * 0.621371)
#   ELSE distance
# END;
#
# D)
# CREATE FUNCTION convert_distance(distance DOUBLE, measure STRING)
# RETURNS DOUBLE
# RETURN
# CASE
#   WHEN measure = "Miles" THEN (distance * 1.60934)
#   WHEN measure = "KM" THEN (distance * 0.621371)
#   ELSE distance
# END;
#
# E)
# CREATE UDF convert_distance(distance DOUBLE, measure STRING)
# RETURNS DOUBLE
# RETURN
# CASE
#   WHEN measure = "Miles" THEN (distance * 1.60934)
#   WHEN measure = "KM" THEN (distance * 0.621371)
#   ELSE distance
# END;
# ```

# %% [markdown]
# ### 10 - Como engenheiro de dados, você está trabalhando em uma tarefa para identificar os funcionários cujo salário é maior que **USD 500.000** dentro de cada departamento da empresa.
# O schema da tabela `company` é apresentado abaixo.
#
#
# | col_name       | data_type                                                                                                   |
# |----------------|--------------------------------------------------------------------------------------------------------------|
# | department_id  | int                                                                                                          |
# | employees      | array&lt;struct&lt;employee_id:int, employee_name:string, employee_salary:double, employee_age:int&gt;&gt; |
#
#
#
# Qual dos trechos de código a seguir pode ser usado para completar essa tarefa?
#
# A)
# ```sql
# SELECT
#   department_id,
#   FETCH(employees, e -> e.employee_salary > 500000) AS employees_with_high_salary
# FROM company;
#
# B)
# SELECT
#   department_id,
#   TRANSFORM(employees, e -> e.employee_salary > 500000) AS employees_with_high_salary
# FROM company;
#
# C)
# SELECT
#   department_id,
#   EXIST(employees, e -> e.employee_salary > 500000) AS employees_with_high_salary
# FROM company;
#
# D)
# SELECT
#   department_id,
#   REDUCE(employees, e -> e.employee_salary > 500000) AS employees_with_high_salary
# FROM company;
#
# E)
# SELECT
#   department_id,
#   FILTER(employees, e -> e.employee_salary > 500000) AS employees_with_high_salary
# FROM company;
# ```
