-- %% [markdown]
-- ## 🕐 Time Travel
-- **Auditar e consultar versões anteriores dos dados:**

-- %%
select * from dea_databricks.bronze.produtos

-- %%
delete from dea_databricks.bronze.produtos
where 1 = 1

-- %%
select * from dea_databricks.bronze.produtos

-- %%
describe history dea_databricks.bronze.produtos

-- %%
select * from dea_databricks.bronze.produtos @v2

-- %%
restore table dea_databricks.bronze.produtos to version as of 2

-- %%
select * from dea_databricks.bronze.produtos

-- %%
describe history dea_databricks.bronze.produtos
