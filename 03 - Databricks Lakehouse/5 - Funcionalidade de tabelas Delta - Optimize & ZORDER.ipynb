-- %% [markdown]
-- ## ⚡ OPTIMIZE - Compactação
-- **Combinar arquivos pequenos em arquivos maiores** para melhor performance
--
-- ## 📊 Z-ORDER - Indexação
-- **Co-localizar informações de colunas** para queries mais rápidas

-- %%
select * from dea_databricks.bronze.produtos

-- %%
describe detail dea_databricks.bronze.produtos

-- %%
INSERT INTO dea_databricks.bronze.produtos (produto_id, nome, categoria, preco, estoque) VALUES (106, 'Headset Gamer', 'Acessórios', 399.90, 18);
INSERT INTO dea_databricks.bronze.produtos (produto_id, nome, categoria, preco, estoque) VALUES (107, 'Cadeira Gamer', 'Móveis', 1299.00, 10);
INSERT INTO dea_databricks.bronze.produtos (produto_id, nome, categoria, preco, estoque) VALUES (108, 'HD Externo 1TB', 'Armazenamento', 420.00, 22);
INSERT INTO dea_databricks.bronze.produtos (produto_id, nome, categoria, preco, estoque) VALUES (109, 'SSD NVMe 512GB', 'Armazenamento', 550.00, 35);
INSERT INTO dea_databricks.bronze.produtos (produto_id, nome, categoria, preco, estoque) VALUES (110, 'Pen Drive 64GB', 'Armazenamento', 79.90, 100)

-- %%
describe detail dea_databricks.bronze.produtos

-- %%
optimize dea_databricks.bronze.produtos
zorder by (produto_id)

-- %%
describe detail dea_databricks.bronze.produtos
