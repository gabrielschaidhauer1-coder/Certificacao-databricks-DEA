-- %% [markdown]
-- ## 🧹 VACUUM - Limpeza
-- **Remover arquivos não utilizados** (arquivos antigos após OPTIMIZE, versões antigas):

-- %%
vacuum dea_databricks.bronze.produtos

-- %%
ALTER TABLE dea_databricks.bronze.produtos SET TBLPROPERTIES ('delta.deletedFileRetentionDuration' = '0 hours');

-- %%
vacuum dea_databricks.bronze.produtos retain 0 hours

-- %%
select * from dea_databricks.bronze.produtos @v1
